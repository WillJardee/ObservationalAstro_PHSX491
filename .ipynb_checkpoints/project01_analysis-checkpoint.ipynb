# %% [markdown]
# # Observation Astronomy Group Project 1: Group 03
# We will be trying to get a CMD of the M15 star cluster: https://en.wikipedia.org/wiki/Messier_15<br>

# %%
# Imports
import numpy as np
import os
from glob import glob
from astropy.io import fits
import astropy.stats

import matplotlib.pyplot as plt
import numpy as np
from astropy import units as u
from astropy.time import Time
from astroplan import FixedTarget, Observer
from astroplan.plots import dark_style_sheet, plot_airmass
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
# %matplotlib inline

from astropy.visualization import astropy_mpl_style, quantity_support
plt.style.use(astropy_mpl_style)
quantity_support()
# Out:
# <astropy.visualization.units.quantity_support.<locals>.MplQuantityConverter at 0x2c33f1c0610>

# %%
# Easy airmass plot
time = Time('2021-10-09 00:00')
target = FixedTarget.from_name('M15')
obs = Observer(name='Bozeman',longitude=-111.0429*u.deg,
               latitude=45.6770*u.deg,elevation=1461*u.m,timezone='US/Mountain')
plot_airmass(target, obs, time, use_local_tz=True)

# %%
# airmass  plot done in local time
# With respect to midnight
m15 = SkyCoord.from_name('M15')
bozeman = EarthLocation(lat=45.6770*u.deg, lon=-111.0429*u.deg, height=1461*u.m)
utcoffset = -6*u.hour  # Mountain Daylight Time: https://www.worldtimebuddy.com/
time = Time('2021-10-09 20:00:00') - utcoffset
m15altaz = m15.transform_to(AltAz(obstime=time,location=bozeman))
print(f"M15's Altitude = {m15altaz.alt:.2}")

# %%
# With 
eight = Time('2021-10-09 20:00:00') - utcoffset
delta_eight = np.linspace(-2, 10, 100)*u.hour
frame_Oct10night = AltAz(obstime=eight+delta_eight, location=bozeman)
m15altazs_Oct10night = m15.transform_to(frame_Oct10night)
m15airmass_Oct10night = m15altazs_Oct10night.secz

# %%
plt.plot(delta_eight, m15airmass_Oct10night)
plt.xlim(-2, 10)
plt.ylim(1, 4)
plt.xlabel('Hours since 8pm MT time')
plt.ylabel('Airmass [Sec(z)]')
plt.show()

# %% [markdown]
# # Plotting and analyzing Oct 09 data

# %%
def plot_it(im, vmin=-1, vmax=-1):
    plt.figure(figsize=(14,10))
    if vmin == -1 and vmax == -1:
        plt.imshow(im,aspect='auto',origin='lower')
    else:
        plt.imshow(im,aspect='auto', vmin=vmin, vmax=vmax,origin='lower')
    plt.colorbar()
    plt.show()

# %%
ls data\observation_2021_10_09\
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4E89-5B0C
#
#  Directory of C:\Users\WillsPc\OneDrive\Documents\GitHub\ObservationalAstro_PHSX491\data\observation_2021_10_09
#
# 10/10/2021  10:03 AM    <DIR>          .
# 10/10/2021  10:03 AM    <DIR>          ..
# 10/05/2021  10:33 AM        18,285,120 CCD Image 1.fit
# 10/09/2021  08:08 PM        18,285,120 CCD Image 10.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 10.fit
# 10/09/2021  08:12 PM        18,285,120 CCD Image 11.000000.fit
# 10/05/2021  10:40 AM        18,285,120 CCD Image 11.fit
# 10/09/2021  09:36 PM        18,285,120 CCD Image 119.fit
# 10/09/2021  08:13 PM        18,285,120 CCD Image 12.000000.fit
# 10/05/2021  10:41 AM        18,285,120 CCD Image 12.fit
# 10/09/2021  09:37 PM        18,285,120 CCD Image 120.fit
# 10/09/2021  09:38 PM        18,285,120 CCD Image 121.fit
# 10/09/2021  09:39 PM        18,285,120 CCD Image 122.fit
# 10/09/2021  09:40 PM        18,285,120 CCD Image 123.fit
# 10/09/2021  09:40 PM        18,285,120 CCD Image 124.fit
# 10/09/2021  09:40 PM        18,285,120 CCD Image 125.fit
# 10/09/2021  09:40 PM        18,285,120 CCD Image 126.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 127.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 128.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 129.fit
# 10/09/2021  08:18 PM        18,285,120 CCD Image 13.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 130.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 131.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 132.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 133.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 134.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 135.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 136.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 137.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 138.fit
# 10/09/2021  09:41 PM        18,285,120 CCD Image 139.fit
# 10/09/2021  08:20 PM        18,285,120 CCD Image 14.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 140.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 141.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 142.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 143.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 144.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 145.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 146.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 147.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 148.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 149.fit
# 10/09/2021  08:20 PM        18,285,120 CCD Image 15.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 150.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 151.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 152.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 153.fit
# 10/09/2021  09:42 PM        18,285,120 CCD Image 154.fit
# 10/09/2021  09:43 PM        18,285,120 CCD Image 155.fit
# 10/09/2021  09:43 PM        18,285,120 CCD Image 156.fit
# 10/09/2021  09:43 PM        18,285,120 CCD Image 157.fit
# 10/09/2021  09:43 PM        18,285,120 CCD Image 158.fit
# 10/09/2021  09:43 PM        18,285,120 CCD Image 159.fit
# 10/09/2021  08:21 PM        18,285,120 CCD Image 16.fit
# 10/09/2021  09:43 PM            25,920 CCD Image 160.fit
# 10/09/2021  08:21 PM        18,285,120 CCD Image 17.fit
# 10/09/2021  08:21 PM        18,285,120 CCD Image 18.fit
# 10/09/2021  08:21 PM        18,285,120 CCD Image 19.fit
# 10/09/2021  07:24 PM        18,285,120 CCD Image 2.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 2.fit
# 10/09/2021  08:21 PM        18,285,120 CCD Image 20.fit
# 10/09/2021  08:21 PM        18,285,120 CCD Image 21.fit
# 10/09/2021  07:25 PM        18,285,120 CCD Image 3.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 3.fit
# 10/09/2021  10:29 PM        18,285,120 CCD Image 362.fit
# 10/09/2021  10:31 PM        18,285,120 CCD Image 363.fit
# 10/09/2021  07:26 PM        18,285,120 CCD Image 4.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 4.fit
# 10/09/2021  07:26 PM        18,285,120 CCD Image 5.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 5.fit
# 10/09/2021  08:00 PM        18,285,120 CCD Image 6.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 6.fit
# 10/09/2021  08:02 PM        18,285,120 CCD Image 7.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 7.fit
# 10/09/2021  08:03 PM        18,285,120 CCD Image 8.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 8.fit
# 10/09/2021  08:06 PM        18,285,120 CCD Image 9.000000.fit
# 10/05/2021  10:34 AM        18,285,120 CCD Image 9.fit
# 10/09/2021  11:18 PM        18,285,120 dark_bias-0001Bias.fit
# 10/09/2021  11:18 PM        18,285,120 dark_bias-0001Dark.fit
# 10/09/2021  11:18 PM        18,285,120 dark_bias-0002Bias.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0002Dark.fit
# 10/09/2021  11:18 PM        18,285,120 dark_bias-0003Bias.fit
# 10/09/2021  11:20 PM        18,285,120 dark_bias-0003Dark.fit
# 10/09/2021  11:18 PM        18,285,120 dark_bias-0004Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0004Dark.fit
# 10/09/2021  11:18 PM        18,285,120 dark_bias-0005Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0005Dark.fit
# 10/09/2021  11:18 PM        18,285,120 dark_bias-0006Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0006Dark.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0007Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0007Dark.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0008Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0008Dark.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0009Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0009Dark.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0010Bias.fit
# 10/09/2021  11:26 PM        18,285,120 dark_bias-0010Dark.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0011Bias.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0012Bias.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0013Bias.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0014Bias.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0015Bias.fit
# 10/09/2021  11:19 PM        18,285,120 dark_bias-0016Bias.fit
# 10/09/2021  11:20 PM        18,285,120 dark_bias-0017Bias.fit
# 10/09/2021  11:20 PM        18,285,120 dark_bias-0018Bias.fit
# 10/09/2021  11:20 PM        18,285,120 dark_bias-0019Bias.fit
# 10/09/2021  11:20 PM        18,285,120 dark_bias-0020Bias.fit
# 10/09/2021  11:20 PM        18,285,120 dark_bias-0021Bias.fit
# 10/09/2021  11:20 PM        18,285,120 dark_bias-0022Bias.fit
# 10/09/2021  11:20 PM        18,285,120 dark_bias-0023Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0024Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0025Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0026Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0027Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0028Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0029Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0030Bias.fit
# 10/09/2021  11:21 PM        18,285,120 dark_bias-0031Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0032Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0033Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0034Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0035Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0036Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0037Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0038Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0039Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0040Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0041Bias.fit
# 10/09/2021  11:22 PM        18,285,120 dark_bias-0042Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0043Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0044Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0045Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0046Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0047Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0048Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0049Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0050Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0051Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0052Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0053Bias.fit
# 10/09/2021  11:23 PM        18,285,120 dark_bias-0054Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0055Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0056Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0057Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0058Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0059Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0060Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0061Bias.fit
# 10/09/2021  11:24 PM        18,285,120 dark_bias-0062Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0063Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0064Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0065Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0066Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0067Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0068Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0069Bias.fit
# 10/09/2021  11:25 PM        18,285,120 dark_bias-0070Bias.fit
# 10/09/2021  07:28 PM        18,285,120 TransitSet11-0001.fit
# 10/09/2021  07:45 PM        18,285,120 TransitSet11-0001B.fit
# 10/09/2021  07:44 PM        18,285,120 TransitSet11-0001G.fit
# 10/09/2021  07:43 PM        18,285,120 TransitSet11-0001R.fit
# 10/09/2021  07:28 PM        18,285,120 TransitSet11-0002.fit
# 10/09/2021  10:28 PM        18,285,120 TransitSet11-0002R.fit
# 10/09/2021  07:29 PM        18,285,120 TransitSet11-0003.fit
# 10/09/2021  10:34 PM        18,285,120 TransitSet11-0003B.fit
# 10/09/2021  10:33 PM        18,285,120 TransitSet11-0003G.fit
# 10/09/2021  10:33 PM        18,285,120 TransitSet11-0003R.fit
# 10/09/2021  07:29 PM        18,285,120 TransitSet11-0004.fit
# 10/09/2021  10:37 PM        18,285,120 TransitSet11-0004B.fit
# 10/09/2021  10:37 PM        18,285,120 TransitSet11-0004G.fit
# 10/09/2021  10:36 PM        18,285,120 TransitSet11-0004R.fit
# 10/09/2021  07:29 PM        18,285,120 TransitSet11-0005.fit
# 10/09/2021  10:40 PM        18,285,120 TransitSet11-0005B.fit
# 10/09/2021  10:39 PM        18,285,120 TransitSet11-0005G.fit
# 10/09/2021  10:38 PM        18,285,120 TransitSet11-0005R.fit
# 10/09/2021  07:29 PM        18,285,120 TransitSet11-0006.fit
# 10/09/2021  10:42 PM        18,285,120 TransitSet11-0006B.fit
# 10/09/2021  10:41 PM        18,285,120 TransitSet11-0006G.fit
# 10/09/2021  10:41 PM        18,285,120 TransitSet11-0006R.fit
# 10/09/2021  07:29 PM        18,285,120 TransitSet11-0007.fit
# 10/09/2021  07:30 PM        18,285,120 TransitSet11-0008.fit
# 10/09/2021  07:30 PM        18,285,120 TransitSet11-0009.fit
# 10/09/2021  07:33 PM        18,285,120 TransitSet11-0010.fit
# 10/09/2021  07:34 PM        18,285,120 TransitSet11-0011.fit
# 10/09/2021  07:35 PM        18,285,120 TransitSet11-0012.fit
# 10/09/2021  07:37 PM        18,285,120 TransitSet11-0013.fit
# 10/09/2021  07:38 PM        18,285,120 TransitSet11-0014.fit
# 10/09/2021  07:40 PM        18,285,120 TransitSet11-0015.fit
#              187 File(s)  3,401,058,240 bytes
#                2 Dir(s)  387,464,261,632 bytes free

# %%
# A little script to get information on all the fits files
def ccdlist(input=None):
    if input is None: input='*.fits'
    files = glob(input)
    nfiles = len(files)
    dt = np.dtype([('file',np.str,100),('naxis1',int),('naxis2',int),
                      ('imagetyp',np.str,100),('exptime',float),('filter',np.str,100)])
    cat = np.zeros(nfiles,dtype=dt)
    for i,f in enumerate(files):
        base = os.path.basename(f)
        base = base.split('.')[0]
        h = fits.getheader(f)
        cat['file'][i] = f
        cat['naxis1'][i] = h.get('naxis1')
        cat['naxis2'][i] = h.get('naxis2')
        cat['imagetyp'][i] = h.get('imagetyp')
        cat['exptime'][i] = h.get('exptime')
        cat['filter'][i] = h.get('filter')
        print(base+'  '+str(cat['naxis1'][i])+'  '+str(cat['naxis2'][i])+'  '+cat['imagetyp'][i]+'  '+str(cat['exptime'][i])+'  '+cat['filter'][i])
    return cat

# %%
out=ccdlist("data/observation_2021_10_09/*.fit")
# Out:
# <ipython-input-16-ac16341c24ce>:6: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dt = np.dtype([('file',np.str,100),('naxis1',int),('naxis2',int),
# <ipython-input-16-ac16341c24ce>:7: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ('imagetyp',np.str,100),('exptime',float),('filter',np.str,100)])
# CCD Image 1  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 10  3380  2704  Flat Field  90.0  Luminance
# CCD Image 10  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 11  3380  2704  Flat Field  90.0  Luminance
# CCD Image 11  3380  2704  Dark Frame  300.0  None
# CCD Image 119  3380  2704  Flat Field  30.0  Luminance
# CCD Image 12  3380  2704  Flat Field  90.0  Luminance
# CCD Image 12  3380  2704  Flat Field  5.0  Green
# CCD Image 120  3380  2704  Flat Field  30.0  Luminance
# CCD Image 121  3380  2704  Flat Field  30.0  Luminance
# CCD Image 122  3380  2704  Flat Field  20.0  Luminance
# CCD Image 123  3380  2704  Flat Field  20.0  Luminance
# CCD Image 124  3380  2704  Flat Field  20.0  Luminance
# CCD Image 125  3380  2704  Light Frame  1.0  Luminance
# CCD Image 126  3380  2704  Light Frame  1.0  Luminance
# CCD Image 127  3380  2704  Light Frame  1.0  Luminance
# CCD Image 128  3380  2704  Light Frame  1.0  Luminance
# CCD Image 129  3380  2704  Light Frame  1.0  Luminance
# CCD Image 13  3380  2704  Flat Field  10.0  Luminance
# CCD Image 130  3380  2704  Light Frame  1.0  Luminance
# CCD Image 131  3380  2704  Light Frame  1.0  Luminance
# CCD Image 132  3380  2704  Light Frame  1.0  Luminance
# CCD Image 133  3380  2704  Light Frame  1.0  Luminance
# CCD Image 134  3380  2704  Light Frame  1.0  Luminance
# CCD Image 135  3380  2704  Light Frame  1.0  Luminance
# CCD Image 136  3380  2704  Light Frame  1.0  Luminance
# CCD Image 137  3380  2704  Light Frame  1.0  Luminance
# CCD Image 138  3380  2704  Light Frame  1.0  Luminance
# CCD Image 139  3380  2704  Light Frame  1.0  Luminance
# CCD Image 14  3380  2704  Flat Field  3.0  Luminance
# CCD Image 140  3380  2704  Light Frame  1.0  Luminance
# CCD Image 141  3380  2704  Light Frame  1.0  Luminance
# CCD Image 142  3380  2704  Light Frame  1.0  Luminance
# CCD Image 143  3380  2704  Light Frame  1.0  Luminance
# CCD Image 144  3380  2704  Light Frame  1.0  Luminance
# CCD Image 145  3380  2704  Light Frame  1.0  Luminance
# CCD Image 146  3380  2704  Light Frame  1.0  Luminance
# CCD Image 147  3380  2704  Light Frame  1.0  Luminance
# CCD Image 148  3380  2704  Light Frame  1.0  Luminance
# CCD Image 149  3380  2704  Light Frame  1.0  Luminance
# CCD Image 15  3380  2704  Flat Field  3.0  Luminance
# CCD Image 150  3380  2704  Light Frame  1.0  Luminance
# CCD Image 151  3380  2704  Light Frame  1.0  Luminance
# CCD Image 152  3380  2704  Light Frame  1.0  Luminance
# CCD Image 153  3380  2704  Light Frame  1.0  Luminance
# CCD Image 154  3380  2704  Light Frame  1.0  Luminance
# CCD Image 155  3380  2704  Light Frame  1.0  Luminance
# CCD Image 156  3380  2704  Light Frame  1.0  Luminance
# CCD Image 157  3380  2704  Light Frame  1.0  Luminance
# CCD Image 158  3380  2704  Light Frame  1.0  Luminance
# CCD Image 159  3380  2704  Light Frame  1.0  Luminance
# CCD Image 16  3380  2704  Flat Field  3.0  Luminance
# CCD Image 160  100  100  Light Frame  1.0  Luminance
# CCD Image 17  3380  2704  Flat Field  3.0  Luminance
# CCD Image 18  3380  2704  Flat Field  3.0  Luminance
# CCD Image 19  3380  2704  Flat Field  3.0  Luminance
# CCD Image 2  3380  2704  Flat Field  5.0  Green
# CCD Image 2  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 20  3380  2704  Flat Field  3.0  Luminance
# CCD Image 21  3380  2704  Flat Field  3.0  Luminance
# CCD Image 3  3380  2704  Flat Field  25.0  Green
# CCD Image 3  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 362  3380  2704  Flat Field  30.0  Blue
# CCD Image 363  3380  2704  Flat Field  30.0  Green
# CCD Image 4  3380  2704  Flat Field  25.0  Red
# CCD Image 4  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 5  3380  2704  Flat Field  25.0  Blue
# CCD Image 5  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 6  3380  2704  Flat Field  5.0  Blue
# CCD Image 6  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 7  3380  2704  Flat Field  30.0  Blue
# CCD Image 7  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 8  3380  2704  Flat Field  60.0  Blue
# CCD Image 8  3380  2704  Bias Frame  0.001000000047497  None
# CCD Image 9  3380  2704  Flat Field  90.0  Luminance
# CCD Image 9  3380  2704  Bias Frame  0.001000000047497  None
# TransitSet11-0001  3380  2704  Light Frame  5.0  Red
# TransitSet11-0001B  3380  2704  Flat Field  60.0  Blue
# TransitSet11-0001G  3380  2704  Flat Field  60.0  Green
# TransitSet11-0001R  3380  2704  Flat Field  60.0  Red
# TransitSet11-0002  3380  2704  Light Frame  5.0  Red
# TransitSet11-0002R  3380  2704  Flat Field  60.0  Red
# TransitSet11-0003  3380  2704  Light Frame  5.0  Red
# TransitSet11-0003B  3380  2704  Flat Field  30.0  Blue
# TransitSet11-0003G  3380  2704  Flat Field  30.0  Green
# TransitSet11-0003R  3380  2704  Flat Field  30.0  Red
# TransitSet11-0004  3380  2704  Light Frame  5.0  Red
# TransitSet11-0004B  3380  2704  Light Frame  30.0  Blue
# TransitSet11-0004G  3380  2704  Light Frame  30.0  Green
# TransitSet11-0004R  3380  2704  Light Frame  30.0  Red
# TransitSet11-0005  3380  2704  Light Frame  5.0  Red
# TransitSet11-0005B  3380  2704  Light Frame  30.0  Blue
# TransitSet11-0005G  3380  2704  Light Frame  30.0  Green
# TransitSet11-0005R  3380  2704  Light Frame  30.0  Red
# TransitSet11-0006  3380  2704  Light Frame  1.0  Red
# TransitSet11-0006B  3380  2704  Light Frame  30.0  Blue
# TransitSet11-0006G  3380  2704  Light Frame  30.0  Green
# TransitSet11-0006R  3380  2704  Light Frame  30.0  Red
# TransitSet11-0007  3380  2704  Light Frame  1.0  Red
# TransitSet11-0008  3380  2704  Light Frame  1.0  Red
# TransitSet11-0009  3380  2704  Flat Field  5.0  Red
# TransitSet11-0010  3380  2704  Flat Field  60.0  Red
# TransitSet11-0011  3380  2704  Flat Field  60.0  Blue
# TransitSet11-0012  3380  2704  Flat Field  60.0  Green
# TransitSet11-0013  3380  2704  Flat Field  60.0  Red
# TransitSet11-0014  3380  2704  Flat Field  60.0  Green
# TransitSet11-0015  3380  2704  Flat Field  60.0  Blue

# %%
print(out[0][0])
# Out:
# data/observation_2021_10_09\CCD Image 1.fit

# %%
im, head = fits.getdata('data/observation_2021_10_09\CCD Image 362.fit',0,header=True)
stats = astropy.stats.sigma_clipped_stats(im)
print(astropy.stats.sigma_clipped_stats(im))
plot_it(im, vmin=stats[0],vmax=stats[0]+stats[2])
# Out:
# (1042.4275261406676, 1042.0, 33.866333873422086)

# %% [raw]
# for i in out:
#     print(i)
#     print(i[0])
#     im, head = fits.getdata(i[0],0,header=True)
#     stats = astropy.stats.sigma_clipped_stats(im)
#     print(astropy.stats.sigma_clipped_stats(im))
#     plot_it(im, stats[0],stats[0]+stats[2])

# %%
im, head = fits.getdata('data/observation_2021_10_09\\CCD Image 12.fit',0,header=True)

# %%
head
# Out:
# SIMPLE  =                    T
# BITPIX  =                   16 /8 unsigned int, 16 & 32 int, -32 & -64 real
# NAXIS   =                    2 /number of axes
# NAXIS1  =                 3380 /fastest changing axis
# NAXIS2  =                 2704 /next to fastest changing axis
# BSCALE  =   1.0000000000000000 /physical = BZERO + BSCALE*array_value
# BZERO   =   32768.000000000000 /physical = BZERO + BSCALE*array_value
# DATE-OBS= '2021-10-05T16:41:50.929'
# EXPTIME =   5.0000000000000000 /Exposure time in seconds
# EXPOSURE=   5.0000000000000000 /Exposure time in seconds
# XPIXSZ  =   3.6899999999999999 /Pixel Width in microns (after binning)
# YPIXSZ  =   3.6899999999999999 /Pixel Height in microns (after binning)
# XBINNING=                    1 /Binning factor in width
# YBINNING=                    1 /Binning factor in height
# XORGSUBF=                    0 /Subframe X position in binned pixels
# YORGSUBF=                    0 /Subframe Y position in binned pixels
# READOUTM= 'Normal  ' /          Readout mode of image
# FILTER  = 'Green   ' /          Filter used when taking image
# IMAGETYP= 'Flat Field' /        Type of image
# FOCALLEN=   0.0000000000000000 /Focal length of telescope in mm
# APTDIA  =   0.0000000000000000 /Aperture diameter of telescope in mm
# APTAREA =   0.0000000000000000 /Aperture area of telescope in mm^2
# SBSTDVER= 'SBFITSEXT Version 1.0' /Version of SBFITSEXT standard in effect
# INPUTV  =   11.640116691589355 /Input Voltage on the camera in V
# HSINKT  =   24.200000762939453 /Camera Heatsink Temperature in deg C
# EGAIN   =  0.15759900212287903 /Electronic gain in e-/ADU
# WIDTH   =                 3380
# HEIGHT  =                 2704
# DRKCOL  =                 3380
# SWCREATE= 'MaxIm DL Version 6.28 211027 1NQU7' /Name of software
# SWSERIAL= '1NQU7-E626Q-541AT-A3KHX-MJPA4-1V' /Software serial number
# JD      =   2459493.1957283448 /Julian Date at time of exposure
# JD-HELIO=   2459493.2013985440 /Heliocentric Julian Date at time of exposure
# OBJECT  = '        '
# TELESCOP= '        ' /          telescope used to acquire this image
# INSTRUME= 'DL Imaging'
# OBSERVER= '        '
# NOTES   = '        '
# ROWORDER= 'TOP-DOWN' /          Image write order, BOTTOM-UP or TOP-DOWN
# FLIPSTAT= '        '
# SWOWNER = 'David Nidever' /     Licensed owner of software

# %%
plot_it(im,65535-100, 65535+100)

# %%
im
# Out:
# array([[ 3205,  3271,  3220, ...,  3219,  3369,  3336],
#        [65535, 65535, 65535, ..., 65535, 65535, 65535],
#        [65535, 65535, 65535, ..., 65535, 65535, 65535],
#        ...,
#        [65535, 65535, 65535, ..., 65535, 65535, 65535],
#        [65535, 65535, 65535, ..., 65535, 65535, 65535],
#        [65535, 65535, 65535, ..., 65535, 65535, 65535]], dtype=uint16)

# %% [raw]
# ls data\observation_2021_10_09\

# %%
im, head = fits.getdata('data/observation_2021_10_09\\CCD Image 12.fit',0,header=True)

# %%
obs_data = []
for i in out:
    im, head = fits.getdata(i[0],0,header=True)
    if head['DATE-OBS'][5:10] == "10-10":
        obs_data.append(i[0])
        print(i[0])
# Out:
# data/observation_2021_10_09\CCD Image 10.000000.fit
# data/observation_2021_10_09\CCD Image 11.000000.fit
# data/observation_2021_10_09\CCD Image 119.fit
# data/observation_2021_10_09\CCD Image 12.000000.fit
# data/observation_2021_10_09\CCD Image 120.fit
# data/observation_2021_10_09\CCD Image 121.fit
# data/observation_2021_10_09\CCD Image 122.fit
# data/observation_2021_10_09\CCD Image 123.fit
# data/observation_2021_10_09\CCD Image 124.fit
# data/observation_2021_10_09\CCD Image 125.fit
# data/observation_2021_10_09\CCD Image 126.fit
# data/observation_2021_10_09\CCD Image 127.fit
# data/observation_2021_10_09\CCD Image 128.fit
# data/observation_2021_10_09\CCD Image 129.fit
# data/observation_2021_10_09\CCD Image 13.fit
# data/observation_2021_10_09\CCD Image 130.fit
# data/observation_2021_10_09\CCD Image 131.fit
# data/observation_2021_10_09\CCD Image 132.fit
# data/observation_2021_10_09\CCD Image 133.fit
# data/observation_2021_10_09\CCD Image 134.fit
# data/observation_2021_10_09\CCD Image 135.fit
# data/observation_2021_10_09\CCD Image 136.fit
# data/observation_2021_10_09\CCD Image 137.fit
# data/observation_2021_10_09\CCD Image 138.fit
# data/observation_2021_10_09\CCD Image 139.fit
# data/observation_2021_10_09\CCD Image 14.fit
# data/observation_2021_10_09\CCD Image 140.fit
# data/observation_2021_10_09\CCD Image 141.fit
# data/observation_2021_10_09\CCD Image 142.fit
# data/observation_2021_10_09\CCD Image 143.fit
# data/observation_2021_10_09\CCD Image 144.fit
# data/observation_2021_10_09\CCD Image 145.fit
# data/observation_2021_10_09\CCD Image 146.fit
# data/observation_2021_10_09\CCD Image 147.fit
# data/observation_2021_10_09\CCD Image 148.fit
# data/observation_2021_10_09\CCD Image 149.fit
# data/observation_2021_10_09\CCD Image 15.fit
# data/observation_2021_10_09\CCD Image 150.fit
# data/observation_2021_10_09\CCD Image 151.fit
# data/observation_2021_10_09\CCD Image 152.fit
# data/observation_2021_10_09\CCD Image 153.fit
# data/observation_2021_10_09\CCD Image 154.fit
# data/observation_2021_10_09\CCD Image 155.fit
# data/observation_2021_10_09\CCD Image 156.fit
# data/observation_2021_10_09\CCD Image 157.fit
# data/observation_2021_10_09\CCD Image 158.fit
# data/observation_2021_10_09\CCD Image 159.fit
# data/observation_2021_10_09\CCD Image 16.fit
# data/observation_2021_10_09\CCD Image 160.fit
# data/observation_2021_10_09\CCD Image 17.fit
# data/observation_2021_10_09\CCD Image 18.fit
# data/observation_2021_10_09\CCD Image 19.fit
# data/observation_2021_10_09\CCD Image 2.000000.fit
# data/observation_2021_10_09\CCD Image 20.fit
# data/observation_2021_10_09\CCD Image 21.fit
# data/observation_2021_10_09\CCD Image 3.000000.fit
# data/observation_2021_10_09\CCD Image 362.fit
# data/observation_2021_10_09\CCD Image 363.fit
# data/observation_2021_10_09\CCD Image 4.000000.fit
# data/observation_2021_10_09\CCD Image 5.000000.fit
# data/observation_2021_10_09\CCD Image 6.000000.fit
# data/observation_2021_10_09\CCD Image 7.000000.fit
# data/observation_2021_10_09\CCD Image 8.000000.fit
# data/observation_2021_10_09\CCD Image 9.000000.fit
# data/observation_2021_10_09\TransitSet11-0001.fit
# data/observation_2021_10_09\TransitSet11-0001B.fit
# data/observation_2021_10_09\TransitSet11-0001G.fit
# data/observation_2021_10_09\TransitSet11-0001R.fit
# data/observation_2021_10_09\TransitSet11-0002.fit
# data/observation_2021_10_09\TransitSet11-0002R.fit
# data/observation_2021_10_09\TransitSet11-0003.fit
# data/observation_2021_10_09\TransitSet11-0003B.fit
# data/observation_2021_10_09\TransitSet11-0003G.fit
# data/observation_2021_10_09\TransitSet11-0003R.fit
# data/observation_2021_10_09\TransitSet11-0004.fit
# data/observation_2021_10_09\TransitSet11-0004B.fit
# data/observation_2021_10_09\TransitSet11-0004G.fit
# data/observation_2021_10_09\TransitSet11-0004R.fit
# data/observation_2021_10_09\TransitSet11-0005.fit
# data/observation_2021_10_09\TransitSet11-0005B.fit
# data/observation_2021_10_09\TransitSet11-0005G.fit
# data/observation_2021_10_09\TransitSet11-0005R.fit
# data/observation_2021_10_09\TransitSet11-0006.fit
# data/observation_2021_10_09\TransitSet11-0006B.fit
# data/observation_2021_10_09\TransitSet11-0006G.fit
# data/observation_2021_10_09\TransitSet11-0006R.fit
# data/observation_2021_10_09\TransitSet11-0007.fit
# data/observation_2021_10_09\TransitSet11-0008.fit
# data/observation_2021_10_09\TransitSet11-0009.fit
# data/observation_2021_10_09\TransitSet11-0010.fit
# data/observation_2021_10_09\TransitSet11-0011.fit
# data/observation_2021_10_09\TransitSet11-0012.fit
# data/observation_2021_10_09\TransitSet11-0013.fit
# data/observation_2021_10_09\TransitSet11-0014.fit
# data/observation_2021_10_09\TransitSet11-0015.fit

# %%
head['DATE-OBS'][5:10]
# Out:
# '10-10'

# %%
obs_data
# Out:
# ['data/observation_2021_10_09\\CCD Image 10.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 11.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 119.fit',
#  'data/observation_2021_10_09\\CCD Image 12.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 120.fit',
#  'data/observation_2021_10_09\\CCD Image 121.fit',
#  'data/observation_2021_10_09\\CCD Image 122.fit',
#  'data/observation_2021_10_09\\CCD Image 123.fit',
#  'data/observation_2021_10_09\\CCD Image 124.fit',
#  'data/observation_2021_10_09\\CCD Image 125.fit',
#  'data/observation_2021_10_09\\CCD Image 126.fit',
#  'data/observation_2021_10_09\\CCD Image 127.fit',
#  'data/observation_2021_10_09\\CCD Image 128.fit',
#  'data/observation_2021_10_09\\CCD Image 129.fit',
#  'data/observation_2021_10_09\\CCD Image 13.fit',
#  'data/observation_2021_10_09\\CCD Image 130.fit',
#  'data/observation_2021_10_09\\CCD Image 131.fit',
#  'data/observation_2021_10_09\\CCD Image 132.fit',
#  'data/observation_2021_10_09\\CCD Image 133.fit',
#  'data/observation_2021_10_09\\CCD Image 134.fit',
#  'data/observation_2021_10_09\\CCD Image 135.fit',
#  'data/observation_2021_10_09\\CCD Image 136.fit',
#  'data/observation_2021_10_09\\CCD Image 137.fit',
#  'data/observation_2021_10_09\\CCD Image 138.fit',
#  'data/observation_2021_10_09\\CCD Image 139.fit',
#  'data/observation_2021_10_09\\CCD Image 14.fit',
#  'data/observation_2021_10_09\\CCD Image 140.fit',
#  'data/observation_2021_10_09\\CCD Image 141.fit',
#  'data/observation_2021_10_09\\CCD Image 142.fit',
#  'data/observation_2021_10_09\\CCD Image 143.fit',
#  'data/observation_2021_10_09\\CCD Image 144.fit',
#  'data/observation_2021_10_09\\CCD Image 145.fit',
#  'data/observation_2021_10_09\\CCD Image 146.fit',
#  'data/observation_2021_10_09\\CCD Image 147.fit',
#  'data/observation_2021_10_09\\CCD Image 148.fit',
#  'data/observation_2021_10_09\\CCD Image 149.fit',
#  'data/observation_2021_10_09\\CCD Image 15.fit',
#  'data/observation_2021_10_09\\CCD Image 150.fit',
#  'data/observation_2021_10_09\\CCD Image 151.fit',
#  'data/observation_2021_10_09\\CCD Image 152.fit',
#  'data/observation_2021_10_09\\CCD Image 153.fit',
#  'data/observation_2021_10_09\\CCD Image 154.fit',
#  'data/observation_2021_10_09\\CCD Image 155.fit',
#  'data/observation_2021_10_09\\CCD Image 156.fit',
#  'data/observation_2021_10_09\\CCD Image 157.fit',
#  'data/observation_2021_10_09\\CCD Image 158.fit',
#  'data/observation_2021_10_09\\CCD Image 159.fit',
#  'data/observation_2021_10_09\\CCD Image 16.fit',
#  'data/observation_2021_10_09\\CCD Image 160.fit',
#  'data/observation_2021_10_09\\CCD Image 17.fit',
#  'data/observation_2021_10_09\\CCD Image 18.fit',
#  'data/observation_2021_10_09\\CCD Image 19.fit',
#  'data/observation_2021_10_09\\CCD Image 2.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 20.fit',
#  'data/observation_2021_10_09\\CCD Image 21.fit',
#  'data/observation_2021_10_09\\CCD Image 3.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 362.fit',
#  'data/observation_2021_10_09\\CCD Image 363.fit',
#  'data/observation_2021_10_09\\CCD Image 4.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 5.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 6.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 7.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 8.000000.fit',
#  'data/observation_2021_10_09\\CCD Image 9.000000.fit',
#  'data/observation_2021_10_09\\TransitSet11-0001.fit',
#  'data/observation_2021_10_09\\TransitSet11-0001B.fit',
#  'data/observation_2021_10_09\\TransitSet11-0001G.fit',
#  'data/observation_2021_10_09\\TransitSet11-0001R.fit',
#  'data/observation_2021_10_09\\TransitSet11-0002.fit',
#  'data/observation_2021_10_09\\TransitSet11-0002R.fit',
#  'data/observation_2021_10_09\\TransitSet11-0003.fit',
#  'data/observation_2021_10_09\\TransitSet11-0003B.fit',
#  'data/observation_2021_10_09\\TransitSet11-0003G.fit',
#  'data/observation_2021_10_09\\TransitSet11-0003R.fit',
#  'data/observation_2021_10_09\\TransitSet11-0004.fit',
#  'data/observation_2021_10_09\\TransitSet11-0004B.fit',
#  'data/observation_2021_10_09\\TransitSet11-0004G.fit',
#  'data/observation_2021_10_09\\TransitSet11-0004R.fit',
#  'data/observation_2021_10_09\\TransitSet11-0005.fit',
#  'data/observation_2021_10_09\\TransitSet11-0005B.fit',
#  'data/observation_2021_10_09\\TransitSet11-0005G.fit',
#  'data/observation_2021_10_09\\TransitSet11-0005R.fit',
#  'data/observation_2021_10_09\\TransitSet11-0006.fit',
#  'data/observation_2021_10_09\\TransitSet11-0006B.fit',
#  'data/observation_2021_10_09\\TransitSet11-0006G.fit',
#  'data/observation_2021_10_09\\TransitSet11-0006R.fit',
#  'data/observation_2021_10_09\\TransitSet11-0007.fit',
#  'data/observation_2021_10_09\\TransitSet11-0008.fit',
#  'data/observation_2021_10_09\\TransitSet11-0009.fit',
#  'data/observation_2021_10_09\\TransitSet11-0010.fit',
#  'data/observation_2021_10_09\\TransitSet11-0011.fit',
#  'data/observation_2021_10_09\\TransitSet11-0012.fit',
#  'data/observation_2021_10_09\\TransitSet11-0013.fit',
#  'data/observation_2021_10_09\\TransitSet11-0014.fit',
#  'data/observation_2021_10_09\\TransitSet11-0015.fit']

# %% [raw]
# for i in obs_data:
#     print(i)
#     im, head = fits.getdata(i,0,header=True)
#     stats = astropy.stats.sigma_clipped_stats(im)
#     print(astropy.stats.sigma_clipped_stats(im))
#     plot_it(im, stats[0],stats[0]+stats[2])
